# %% [markdown]
# # Linear Regression

# %% [markdown]
# Linear regression analysis is the most widely used of all statistical techniques: it is the study of linear, additive relationships between variables.   Let Y denote the “dependent” variable whose values you wish to predict, and let X1, …,Xk denote the “independent” variables from which you wish to predict it, with the value of variable Xi in period t (or in row t of the data set) denoted by Xit.  Then the equation for computing the predicted value of Yt is:

# %% [markdown]
# ![alt text](http://resources.esri.com/help/9.3/arcgisdesktop/com/gp_toolref/spatial_statistics_toolbox/regression%20equation%20cartoon.png)

# %% [markdown]
# This formula has the property that the prediction for Y is a straight-line function of each of the X variables, holding the others fixed, and the contributions of different X variables to the predictions are additive.  The slopes of their individual straight-line relationships with Y are the constants b1, b2, …, bk, the so-called coefficients of the variables.   That is, bi is the change in the predicted value of Y per unit of change in Xi, other things being equal.  The additional constant b0, the so-called intercept, is the prediction that the model would make if all the X’s were zero (if that is possible).   The coefficients and intercept are estimated by least squares, i.e., setting them equal to the unique values that minimize the sum of squared errors within the sample of data to which the model is fitted. And the model's prediction errors are typically assumed to be independently and identically normally distributed.

# %% [markdown]
# ### Linear regression is a linear approximation of casual relationship between two or more variables

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/linr.PNG)

# %% [markdown]
# ## Difference between correlation and regression

# %% [markdown]
# Correlation is a single point and the relationship between the variables

# %% [markdown]
# regression is the prediction of one variable from other variables

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/corr.PNG)

# %% [markdown]
# # OLS(ordinary least squares)

# %% [markdown]
# Ordinary Least Squares (OLS) linear regression is a statistical technique used for the analysis and modelling of linear relationships between a response variable and one or more predictor variables. If the relationship between two variables appears to be linear, then a straight line can be fit to the data in order to model the relationship

# %% [markdown]
# ### we use ols method for linear regression by minimizing the error values(SSE)

# %% [markdown]
# ![alt text](http://economya.ir/wp-content/uploads/linegraph.jpg)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/olss.PNG)

# %% [markdown]
# # R2(r-sqaured) value

# %% [markdown]
# Interpretation. R2 is a statistic that will give some information about the goodness of fit of a model. In regression, the R2 coefficient of determination is a statistical measure of how well the regression line approximates the real data points. An R2 of 1 indicates that the regression line perfectly fits the data

# %% [markdown]
# ![alt text](https://www.graphpad.com/guides/prism/7/curve-fitting/_bm35.png)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/ssesst.PNG)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/r2v.PNG)

# %% [markdown]
# # Hypothesis testing(p-value approach)

# %% [markdown]
# The p-value is the level of marginal significance within a statistical hypothesis test representing the probability of the occurrence of a given event. The p-value is used as an alternative to rejection points to provide the smallest level of significance at which the null hypothesis would be rejected.

# %% [markdown]
# The p-value for each term tests the null hypothesis that the coefficient is equal to zero (no effect). A low p-value (< 0.05) indicates that you can reject the null hypothesis

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/pvalue1.PNG)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/pval2.PNG)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/pvale3.PNG)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/pval4.PNG)

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/pval5.PNG)

# %% [markdown]
# # Assumptions to linear regression(OLS approach)

# %% [markdown]
# ## - 1) Linearity
#
# ## -2) No endogeneity(independence)-covariance of error is zero
#
# ## -3) Normality(expected value of errors is zero, normalizing error) and homoscedasticity(constant variance)
#
# ## -4) No autocorrelation
#
# ## -5) No multicollinearity

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/praneethmetuku/file/master/ols%20assum%20line%20reg.PNG)

# %% [markdown]
# # Practical examples of linear regression

# %% [markdown]
# # Example:1 USA_Housing dataset

# %% [markdown]
# ### step1:- loading import statements

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step2:- loading dataset and analyzing the dataset

# %%
data=pd.read_csv("https://raw.githubusercontent.com/praneethmetuku/file/master/USA_Housing.csv")

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
# Avg. Area Income                5000 non-null float64
# Avg. Area House Age             5000 non-null float64
# Avg. Area Number of Rooms       5000 non-null float64
# Avg. Area Number of Bedrooms    5000 non-null float64
# Area Population                 5000 non-null float64
# Price                           5000 non-null float64
# Address                         5000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 273.5+ KB

# %%
data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
data.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %% [markdown]
# ### Step3:- visualizing the dataset

# %%
sns.set_palette('coolwarm')

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.pairplot(data)

# %% [markdown]
# see correlation through the scatter plots and analyze the predicted price column

# %%
sns.heatmap(data.corr())

# %%
#see the distplot for predicted value here its price column

# %%
sns.distplot(data['Price'])

# %% [markdown]
# ### Step-4 split data into training and testing set3

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
y=data['Price']
x=data[['Avg. Area Income', 'Avg. Area House Age','Area Population','Avg. Area Number of Bedrooms']]

# %%
print(x)
# Out:
#       Avg. Area Income  Avg. Area House Age  Area Population  \
# 0         79545.458574             5.682861     23086.800503
# 1         79248.642455             6.002900     40173.072174
# 2         61287.067179             5.865890     36882.159400
# 3         63345.240046             7.188236     34310.242831
# 4         59982.197226             5.040555     26354.109472
# 5         80175.754159             4.988408     26748.428425
# 6         64698.463428             6.025336     60828.249085
# 7         78394.339278             6.989780     36516.358972
# 8         59927.660813             5.362126     29387.396003
# 9         81885.927184             4.423672     40149.965749
# 10        80527.472083             8.093513     47224.359840
# 11        50593.695497             4.496513     34343.991886
# 12        39033.809237             7.671755     39220.361467
# 13        73163.663441             6.919535     32326.123139
# ...

# %%
print(y)
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
# 5       1.068138e+06
# 6       1.502056e+06
# 7       1.573937e+06
# 8       7.988695e+05
# 9       1.545155e+06
# 10      1.707046e+06
# 11      6.637324e+05
# 12      1.042814e+06
# 13      1.291332e+06
# 14      1.402818e+06
# 15      1.306675e+06
# 16      1.556787e+06
# 17      5.284852e+05
# 18      1.019426e+06
# 19      1.030591e+06
# 20      2.146925e+06
# 21      9.292476e+05
# 22      7.188872e+05
# 23      7.439998e+05
# 24      8.957371e+05
# 25      1.453975e+06
# 26      1.125693e+06
# 27      9.754295e+05
# 28      1.240764e+06
# 29      1.577018e+06
#             ...
# 4970    1.120943e+06
# 4971    1.111307e+06
# 4972    1.736402e+06
# 4973    1.340770e+06
# 4974    8.013486e+05
# 4975    1.324382e+06
# 4976    1.340344e+06
# 4977    1.518478e+06
# 4978    1.910585e+06
# 4979    1.823498e+06
# 4980    1.406865e+06
# 4981    1.203850e+06
# ...

# %%
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\metuk\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=101)

# %%
x_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Area Population  \
# 2654      86690.873301             6.259901     42589.624391
# 2468      59866.947700             5.870330     32064.597156
# 290       74372.138452             6.562380     34321.960155
# 1463      61370.323490             6.529605     20600.511000
# 4508      52652.652336             5.688943     34776.585907
# 4263      83656.489308             7.553569     42841.741623
# 2065      67683.203074             6.170046     31420.299236
# 658       73829.777741             6.130263     51385.523241
# 157       56063.480867             5.106935     39129.296705
# 4307      69442.445387             5.967036     56984.145247
# 4822      57868.266632             6.042907     45196.153964
# 453       71356.302732             5.156589     36998.479789
# 1706      74656.894238             6.115160     22602.133570
# 2352      81665.578346             5.565926     34753.882892
# ...

# %%
y_test
# Out:
# 1718    1.251689e+06
# 2511    8.730483e+05
# 345     1.696978e+06
# 2521    1.063964e+06
# 54      9.487883e+05
# 2866    7.300436e+05
# 2371    1.166925e+06
# 2952    7.054441e+05
# 45      1.499989e+06
# 4653    1.288199e+06
# 891     1.441737e+06
# 3011    1.279681e+06
# 335     1.754969e+06
# 3050    1.511653e+06
# 3850    1.441956e+06
# 834     1.119993e+06
# 3188    7.278665e+05
# 4675    1.138885e+06
# 2564    1.074263e+06
# 1866    1.386473e+06
# 1492    4.046436e+05
# 3720    1.449829e+06
# 618     1.775875e+06
# 3489    1.202051e+06
# 2145    1.105737e+06
# 3200    1.835565e+06
# 4752    1.795429e+06
# 602     1.424283e+06
# 4665    1.365945e+06
# 79      1.492011e+06
#             ...
# 4809    9.870264e+05
# 3983    8.562076e+05
# 2641    1.086186e+06
# 4921    1.609092e+06
# 747     1.539959e+06
# 162     1.877402e+06
# 3044    1.142128e+06
# 4737    1.798522e+06
# 2209    1.293384e+06
# 4245    6.978406e+05
# 750     1.850526e+06
# 792     9.490722e+05
# ...

# %% [markdown]
# ### Step-5 fitting training sets

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_
# Out:
# array([2.14366079e+01, 1.63154590e+05, 1.55558081e+01, 4.70540251e+04])

# %%
lm.intercept_
# Out:
# -1962177.3685010846

# %%
x_train.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Area Population',
#        'Avg. Area Number of Bedrooms'],
#       dtype='object')

# %%
coef_df=pd.DataFrame(data=lm.coef_,index=x_train.columns,columns=['coeffvalues'])

# %%
coef_df
# Out:
#                                 coeffvalues
# Avg. Area Income                  21.436608
# Avg. Area House Age           163154.589551
# Area Population                   15.555808
# Avg. Area Number of Bedrooms   47054.025077

# %% [markdown]
#  for 1 unit increase in Avg. Area Income there 21.43 increase in price value and so on....

# %% [markdown]
# ### Step-6 Predicting the test datasets

# %%
y_predictions=lm.predict(x_test)

# %%
# y_predictions is the predicted values of y_test with x_test values and #y_test is the true values of the dataset

# %%
plt.scatter(y_test,y_predictions)
plt.xlabel('true y_test values')
plt.ylabel('predicted y_test values')
# Out:
# Text(0,0.5,'predicted y_test values')

# %%
sns.distplot(y_predictions) #if distplot is normally distributed the linear regression is the right model to choose

# %% [markdown]
# ### Step-7 Evaluation report

# %%
from scipy import stats

# %%
p=stats.linregress(y_test,y_predictions)

# %%
p
# Out:
# LinregressResult(slope=0.8351375998416527, intercept=208084.98208900134, rvalue=0.9090129880889135, pvalue=0.0, stderr=0.009892958443721908)

# %%
print(p.rvalue)
r2value=np.sqrt(p.rvalue)
r2value
# Out:
# 0.9090129880889135
# 0.9534217262517745

# %%
from sklearn import metrics
print("MAE",metrics.mean_absolute_error(y_test,y_predictions))
r2_value=metrics.explained_variance_score(y_test,y_predictions)
r2_value
# Out:
# MAE 115437.65855447893
# 0.8262101901137548

# %% [markdown]
# # Example:-2 Salaray_data dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('https://raw.githubusercontent.com/praneethmetuku/file/master/Salary_Data.csv')

# %%
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
# YearsExperience    30 non-null float64
# Salary             30 non-null float64
# dtypes: float64(2)
# memory usage: 560.0 bytes

# %%
data.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.set_palette('coolwarm')

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr())

# %%
sns.distplot(data['Salary'])

# %%
data.columns
# Out:
# Index(['YearsExperience', 'Salary'], dtype='object')

# %%
x=data.iloc[:,:-1].values
y=data.iloc[:,1:].values

# %%
from sklearn.cross_validation import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
# array([[ 7.9],
#        [ 2.9],
#        [ 5.1],
#        [ 3.2],
#        [ 4.5],
#        [ 8.2],
#        [ 6.8],
#        [ 1.3],
#        [10.5],
#        [ 3. ],
#        [ 2.2],
#        [ 5.9],
#        [ 6. ],
#        [ 3.7],
#        [ 3.2],
#        [ 9. ],
#        [ 2. ],
#        [ 1.1],
#        [ 7.1],
#        [ 4.9],
#        [ 4. ]])

# %%
y_train
# Out:
# array([[101302.],
#        [ 56642.],
#        [ 66029.],
#        [ 64445.],
#        [ 61111.],
#        [113812.],
#        [ 91738.],
#        [ 46205.],
#        [121872.],
#        [ 60150.],
#        [ 39891.],
#        [ 81363.],
#        [ 93940.],
#        [ 57189.],
#        [ 54445.],
#        [105582.],
#        [ 43525.],
#        [ 39343.],
#        [ 98273.],
#        [ 67938.],
#        [ 56957.]])

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_
# Out:
# array([[9360.26128619]])

# %%
lm.intercept_
# Out:
# array([26777.3913412])

# %%
y_pred=lm.predict(x_test)

# %%
plt.scatter(y_test,y_pred,color='orange')

# %%
sns.distplot(y_pred)

# %%
from sklearn import metrics
print("mae",metrics.mean_absolute_error(y_test,y_pred))
# Out:
# mae 3737.4178618788987

# %%
r2value=metrics.explained_variance_score(y_test,y_pred)
r2value
# Out:
# 0.9772844627508654

# %% [markdown]
# # Example-3 (IMDB) dataset imdb score predictions
#
# https://nycdatascience.com/blog/student-works/web-scraping/movie-rating-prediction/

# %% [markdown]
# ### Step1:- Loading the import statments

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Step2:-Loading the dataset

# %%
data=pd.read_csv('https://raw.githubusercontent.com/sundeepblue/movie_rating_prediction/master/movie_metadata.csv')

# %%
data
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 4                  NaN         Doug Walker                     NaN       NaN
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# ...

# %% [markdown]
# ### Step3:- Analyzing the dataset and removing the missing values

# %%
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
data.isnull().any()
# Out:
# color                         True
# director_name                 True
# num_critic_for_reviews        True
# duration                      True
# director_facebook_likes       True
# actor_3_facebook_likes        True
# actor_2_name                  True
# actor_1_facebook_likes        True
# gross                         True
# genres                       False
# actor_1_name                  True
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                  True
# facenumber_in_poster          True
# plot_keywords                 True
# movie_imdb_link              False
# num_user_for_reviews          True
# language                      True
# country                       True
# content_rating                True
# budget                        True
# title_year                    True
# actor_2_facebook_likes        True
# imdb_score                   False
# aspect_ratio                  True
# ...

# %%
data.fillna(value=0,axis=1,inplace=True)

# %%
data.isnull().any()
# Out:
# color                        False
# director_name                False
# num_critic_for_reviews       False
# duration                     False
# director_facebook_likes      False
# actor_3_facebook_likes       False
# actor_2_name                 False
# actor_1_facebook_likes       False
# gross                        False
# genres                       False
# actor_1_name                 False
# movie_title                  False
# num_voted_users              False
# cast_total_facebook_likes    False
# actor_3_name                 False
# facenumber_in_poster         False
# plot_keywords                False
# movie_imdb_link              False
# num_user_for_reviews         False
# language                     False
# country                      False
# content_rating               False
# budget                       False
# title_year                   False
# actor_2_facebook_likes       False
# imdb_score                   False
# aspect_ratio                 False
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5043 non-null object
# director_name                5043 non-null object
# num_critic_for_reviews       5043 non-null float64
# duration                     5043 non-null float64
# director_facebook_likes      5043 non-null float64
# actor_3_facebook_likes       5043 non-null float64
# actor_2_name                 5043 non-null object
# actor_1_facebook_likes       5043 non-null float64
# gross                        5043 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5043 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5043 non-null object
# facenumber_in_poster         5043 non-null float64
# ...

# %%
data.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             5043.000000  5043.000000              5043.000000
# mean               138.804283   106.882213               672.351576
# std                121.792053    25.828463              2785.871819
# min                  0.000000     0.000000                 0.000000
# 25%                 48.000000    93.000000                 6.000000
# 50%                109.000000   103.000000                45.000000
# 75%                194.000000   118.000000               189.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5043.000000             5043.000000  5.043000e+03
# mean               642.068015             6550.941305  3.997226e+07
# std               1661.808199            15012.315824  6.483779e+07
# min                  0.000000                0.000000  0.000000e+00
# ...

# %%
data.corr()
# Out:
#                            num_critic_for_reviews  duration  \
# num_critic_for_reviews                   1.000000  0.269515
# duration                                 0.269515  1.000000
# director_facebook_likes                  0.184912  0.161133
# actor_3_facebook_likes                   0.273082  0.123773
# actor_1_facebook_likes                   0.193252  0.089176
# gross                                    0.524832  0.254709
# num_voted_users                          0.626616  0.313818
# cast_total_facebook_likes                0.266110  0.123135
# facenumber_in_poster                    -0.033915  0.004436
# num_user_for_reviews                     0.611972  0.329743
# budget                                   0.127850  0.074762
# title_year                               0.153433  0.262090
# actor_2_facebook_likes                   0.284345  0.131826
# imdb_score                               0.299677  0.256352
# aspect_ratio                             0.054952 -0.017209
# ...

# %% [markdown]
# ### Step-4 Visualizing the dataset

# %%
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4      0        Doug Walker                     0.0       0.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     0.0        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),cmap='RdBu')

# %%
sns.distplot(data['imdb_score'])

# %% [markdown]
# ### Step-5 splitting the data into train and test set

# %%
data.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
x=data[['actor_3_facebook_likes', 'actor_1_facebook_likes',
        'facenumber_in_poster',
       'num_critic_for_reviews', 'budget', 'title_year',
       'actor_2_facebook_likes', 'aspect_ratio']]

y=data['imdb_score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#       actor_3_facebook_likes  actor_1_facebook_likes  facenumber_in_poster  \
# 4190                     4.0                    15.0                   1.0
# 3394                   660.0                   883.0                   2.0
# 2743                  1000.0                 14000.0                   0.0
# 2631                   566.0                   925.0                   1.0
# 1556                   642.0                 16000.0                   5.0
# 527                    988.0                 11000.0                   0.0
# 3353                   636.0                  2000.0                   1.0
# 1230                   720.0                 15000.0                   1.0
# 3034                   808.0                  1000.0                   3.0
# 4224                   385.0                 11000.0                   0.0
# 4978                   128.0                   968.0                   0.0
# ...

# %%
y_test
# Out:
# 3937    7.1
# 3382    7.0
# 1965    5.1
# 3819    7.4
# 2172    7.1
# 3277    8.5
# 2062    6.1
# 4881    4.4
# 3701    5.8
# 3046    5.5
# 4171    7.8
# 113     5.5
# 381     6.2
# 2689    7.0
# 1986    5.8
# 2971    6.0
# 3388    7.1
# 1196    7.8
# 2816    6.5
# 4300    7.4
# 2940    5.4
# 4626    3.9
# 556     6.6
# 1865    7.5
# 534     7.3
# 2518    3.6
# 2806    6.7
# 4293    6.4
# 2545    8.0
# 265     7.1
#        ...
# 925     4.9
# 2907    8.0
# 1934    3.3
# 1803    7.2
# 4632    7.1
# 2219    7.6
# 1422    6.4
# 2719    7.5
# 4131    5.5
# 2735    7.2
# 4539    7.0
# 1837    6.0
# 3978    7.1
# 3342    7.2
# 1551    4.4
# 2781    6.4
# 1273    7.0
# 1288    6.2
# 1493    5.1
# 3887    8.0
# 1900    6.8
# 4785    6.8
# 3144    6.5
# 4156    5.3
# 3063    7.4
# 2939    6.0
# 3236    5.9
# 687     5.0
# 1977    6.3
# 3972    6.8
# Name: imdb_score, Length: 1513, dtype: float64

# %% [markdown]
# ### Step-6 fitting the training set

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
lm.coef_
# Out:
# array([-4.64761119e-05,  1.02760429e-06, -2.68131431e-02,  3.11675062e-03,
#        -5.17702444e-11, -7.29686016e-04,  1.43417285e-05,  1.99766078e-02])

# %%
lm.intercept_
# Out:
# 7.4349630319505104

# %%
p=pd.DataFrame(lm.coef_,index=x_train.columns,columns=['indivual coeff values'])

# %%
p
# Out:
#                         indivual coeff values
# actor_3_facebook_likes          -4.647611e-05
# actor_1_facebook_likes           1.027604e-06
# facenumber_in_poster            -2.681314e-02
# num_critic_for_reviews           3.116751e-03
# budget                          -5.177024e-11
# title_year                      -7.296860e-04
# actor_2_facebook_likes           1.434173e-05
# aspect_ratio                     1.997661e-02

# %% [markdown]
# ### Step-7 predicting the test set

# %%
y_predtest=lm.predict(x_test)

# %%
plt.scatter(y_test,y_predtest)

# %%
sns.distplot(y_predtest)

# %% [markdown]
# ### Step-8 evaluation report

# %%
from scipy import stats
p=stats.linregress(y_test,y_predtest)
p
# Out:
# LinregressResult(slope=0.13454554424325763, intercept=5.5833300416701, rvalue=0.3561933177338303, pvalue=1.747152759256798e-46, stderr=0.009080083869680502)

# %%
from sklearn import metrics
print("MAE",metrics.mean_absolute_error(y_test,y_predtest))
# Out:
# MAE 0.8162719214124475

# %%
metrics.explained_variance_score(y_test,y_predtest)
# Out:
# 0.126409773236268

# %% [markdown]
# # Example-4 Ecommerce customers dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('https://raw.githubusercontent.com/praneethmetuku/file/master/Ecommerce%20Customers.csv')

# %%
data.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Email                   500 non-null object
# Address                 500 non-null object
# Avatar                  500 non-null object
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 31.3+ KB

# %%
data.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
data.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
sns.set_palette('cubehelix')

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr())

# %%
data.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
x=data[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]
y=data['Yearly Amount Spent']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 141            31.851253    12.418962        35.977652              3.251742
# 383            34.188184    13.130022        35.429334              3.790552
# 135            33.358398    12.703688        36.100914              2.724108
# 493            32.060914    12.625433        35.539142              5.412358
# 122            33.268330    11.113330        37.387946              4.018727
# 22             31.531604    13.378563        38.734006              2.245148
# 68             32.430758    11.306232        37.680403              2.779521
# 20             32.912785    11.365492        37.607793              4.599937
# 382            33.587373     9.953995        37.345739              3.215667
# 14             32.387976    13.148726        36.619957              2.494544
# 278            32.607903    13.677246        37.744700              2.871948
# ...

# %%
x_test
# Out:
#      Avg. Session Length  Time on App  Time on Website  Length of Membership
# 90             32.491447    12.530357        37.875219              2.476139
# 254            32.711119    12.326291        36.673878              3.350279
# 283            33.077731    11.466984        35.675728              1.809230
# 445            32.212924    11.732991        35.633954              4.331863
# 461            32.770492    11.371767        35.261498              4.034386
# 15             30.737720    12.636606        36.213763              3.357847
# 316            33.566474    12.235659        37.277573              2.532044
# 489            32.246350    11.305551        37.133127              1.707390
# 159            34.568681    11.378087        38.304471              3.784932
# 153            31.945396    12.965761        36.966389              6.076654
# 241            32.686245    12.638572        36.097221              4.297737
# ...

# %%
from sklearn.linear_model import LinearRegression
lm=LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
p=lm.coef_
np.set_printoptions(suppress=True)#used to disable scientific notation in ndarrays(optional)
# pd.set_option('display.float_format', lambda x: '%.3f' % x)(for pandas)
p
# Out:
# array([25.76752967, 38.80039355, -0.01804092, 61.85256792])

# %%
lm.intercept_
# Out:
# -1037.8257485695394

# %%
pd.DataFrame(p,index=x.columns,columns=['coef'])
# Out:
#                       coef
# Avg. Session Length  25.77
# Time on App          38.80
# Time on Website      -0.02
# Length of Membership 61.85

# %%
#one unit increase in time on app will increase 38.80 amount increase in yearly amount spent

# %%
y_predict=lm.predict(x_test)

# %%
plt.scatter(y_test,y_predict)

# %%
from scipy import stats
p=stats.linregress(y_test,y_predict)
p
# Out:
# LinregressResult(slope=0.9971459932883526, intercept=1.6953716622010688, rvalue=0.9925154400844132, pvalue=4.605999722206429e-137, stderr=0.010084969790650041)

# %%
from sklearn import metrics
r2=metrics.explained_variance_score(y_test,y_predict)
r2
# Out:
# 0.984939275525299

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, y_predict))
print('MSE:', metrics.mean_squared_error(y_test, y_predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# MAE: 7.8513771708614435
# MSE: 94.55779479273288
# RMSE: 9.724083236620967
